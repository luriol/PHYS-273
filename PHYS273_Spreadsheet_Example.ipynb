# %%
from google.colab import files
import io
import pandas as pd

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d69e0f6e-0dde-4c0a-8796-7a372e2f7490" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d69e0f6e-0dde-4c0a-8796-7a372e2f7490">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PHYS273 test 1 - Sheet1.csv to PHYS273 test 1 - Sheet1 (2).csv

# %%
#assign the filename after you upload the sheet
df2 = pd.read_csv(io.BytesIO(uploaded['PHYS273 test 1 - Sheet1.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
from matplotlib import pyplot as plt
plt.plot(df2['x-axis'],df2['y-axis'])
